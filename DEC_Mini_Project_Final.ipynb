# %% [markdown]
# # DEC Mini Project

# %% [markdown]
# ## Group Members-
# Jatin Garad (1032210494),
# Rusheil Baath (1032210707),
# Ocean Bhandari (1032211058),
# Aman Bendre (1032210467)

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading/Loading the dataset
df = pd.read_csv('/content/milknew.csv')
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %%
#Number of rows and columns in the dataset
df.shape
# Out:
# (1059, 8)

# %%
#To find mean of data
df.mean()
# Out:
# <ipython-input-735-f8158d1204e4>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# pH              6.630123
# Temprature     44.226629
# Taste           0.546742
# Odor            0.432483
# Fat             0.671388
# Turbidity       0.491029
# Colour        251.840415
# dtype: float64

# %%
df.mode()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour Grade
# 0  6.8          45      1     0     1          0     255   low

# %%
df.head(10)
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium
# 5  6.6          37      1     1     1          1     255    high
# 6  5.5          45      1     0     1          1     250     low
# 7  4.5          60      0     1     1          1     250     low
# 8  8.1          66      1     0     1          1     255     low
# 9  6.7          45      1     1     0          0     247  medium

# %%
df.tail(10)
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 1049  6.5          37      0     0     0          0     255  medium
# 1050  6.6          37      1     1     1          1     255    high
# 1051  5.5          45      1     0     1          1     250     low
# 1052  6.5          40      1     0     0          0     250  medium
# 1053  8.1          66      1     0     1          1     255     low
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low

# %%
df.dtypes
# Out:
# pH            float64
# Temprature      int64
# Taste           int64
# Odor            int64
# Fat             int64
# Turbidity       int64
# Colour          int64
# Grade          object
# dtype: object

# %%
df.columns
# Out:
# Index(['pH', 'Temprature', 'Taste', 'Odor', 'Fat ', 'Turbidity', 'Colour',
#        'Grade'],
#       dtype='object')

# %%
df.size
# Out:
# 8472

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#                 pH   Temprature        Taste         Odor         Fat   \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean      6.630123    44.226629     0.546742     0.432483     0.671388
# std       1.399679    10.098364     0.498046     0.495655     0.469930
# min       3.000000    34.000000     0.000000     0.000000     0.000000
# 25%       6.500000    38.000000     0.000000     0.000000     0.000000
# 50%       6.700000    41.000000     1.000000     0.000000     1.000000
# 75%       6.800000    45.000000     1.000000     1.000000     1.000000
# max       9.500000    90.000000     1.000000     1.000000     1.000000
#
#          Turbidity       Colour
# count  1059.000000  1059.000000
# mean      0.491029   251.840415
# std       0.500156     4.307424
# min       0.000000   240.000000
# 25%       0.000000   250.000000
# 50%       0.000000   255.000000
# 75%       1.000000   255.000000
# max       1.000000   255.000000

# %%
df["Temprature"].mean()
# Out:
# 44.226628895184135

# %%
df["Temprature"].count()
# Out:
# 1059

# %%
df.iloc[10:20]
# Out:
#      pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 10  6.7          45      1     1     1          0     245  medium
# 11  5.6          50      0     1     1          1     255     low
# 12  8.6          55      0     1     1          1     255     low
# 13  7.4          90      1     0     1          1     255     low
# 14  6.8          45      0     1     1          1     255    high
# 15  6.5          38      1     0     0          0     255  medium
# 16  4.7          38      1     0     1          0     255     low
# 17  3.0          40      1     1     1          1     255     low
# 18  9.0          43      1     0     1          1     250     low
# 19  6.8          40      1     0     1          0     245  medium

# %%
#bar graph
df['Temprature'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#pie chart
df['Temprature'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Temprature'>

# %%
df.isna()
# Out:
#          pH  Temprature  Taste   Odor   Fat   Turbidity  Colour  Grade
# 0     False       False  False  False  False      False   False  False
# 1     False       False  False  False  False      False   False  False
# 2     False       False  False  False  False      False   False  False
# 3     False       False  False  False  False      False   False  False
# 4     False       False  False  False  False      False   False  False
# ...     ...         ...    ...    ...    ...        ...     ...    ...
# 1054  False       False  False  False  False      False   False  False
# 1055  False       False  False  False  False      False   False  False
# 1056  False       False  False  False  False      False   False  False
# 1057  False       False  False  False  False      False   False  False
# 1058  False       False  False  False  False      False   False  False
#
# [1059 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# pH            0
# Temprature    0
# Taste         0
# Odor          0
# Fat           0
# Turbidity     0
# Colour        0
# Grade         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 976

# %%
#Finding out the percent of missing values upto 5 decimal places
round((df.isna().sum()/len(df))*100,5)
# Out:
# pH            0.0
# Temprature    0.0
# Taste         0.0
# Odor          0.0
# Fat           0.0
# Turbidity     0.0
# Colour        0.0
# Grade         0.0
# dtype: float64

# %%
#Dropping duplicate columns
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0    6.6          35      1     0     1          0     254    high
# 1    6.6          36      0     1     0          1     253    high
# 2    8.5          70      1     1     1          1     246     low
# 3    9.5          34      1     1     0          1     255     low
# 4    6.6          37      0     0     0          0     255  medium
# ..   ...         ...    ...   ...   ...        ...     ...     ...
# 930  6.6          38      0     1     1          1     255    high
# 942  6.6          45      1     0     0          1     255  medium
# 957  6.8          41      1     1     1          0     255    high
# 985  6.5          45      1     0     0          0     246  medium
# 998  6.6          43      0     0     0          1     250  medium
#
# [83 rows x 8 columns]

# %% [markdown]
# # Min-Max Normalisation

# %%
#MIN MAX NORMALIZATION
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
#Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(df[['Temprature']].values.astype(float))

# %%
#Run the normalizer on the dataframes
df.normalized = pd.DataFrame(x_scaled)
df['pH']=x_scaled
df.sort_values(by='Temprature')
df[['Temprature','pH']]
# Out:
# <ipython-input-757-45257da2f8b4>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.normalized = pd.DataFrame(x_scaled)
#      Temprature        pH
# 0            35  0.017857
# 1            36  0.035714
# 2            70  0.642857
# 3            34  0.000000
# 4            37  0.053571
# ..          ...       ...
# 930          38  0.071429
# 942          45  0.196429
# 957          41  0.125000
# 985          45  0.196429
# 998          43  0.160714
#
# [83 rows x 2 columns]

# %% [markdown]
# # Correlation

# %%
df.corr(method='pearson')
# Out:
# <ipython-input-758-432dd9d4238b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                   pH  Temprature     Taste      Odor      Fat   Turbidity  \
# pH          1.000000    1.000000  0.016413 -0.002800  0.034489   0.150841
# Temprature  1.000000    1.000000  0.016413 -0.002800  0.034489   0.150841
# Taste       0.016413    0.016413  1.000000 -0.014831  0.359513   0.010545
# Odor       -0.002800   -0.002800 -0.014831  1.000000  0.257576   0.381837
# Fat         0.034489    0.034489  0.359513  0.257576  1.000000   0.164585
# Turbidity   0.150841    0.150841  0.010545  0.381837  0.164585   1.000000
# Colour     -0.030160   -0.030160 -0.062734 -0.072173  0.093818   0.051957
#
#               Colour
# pH         -0.030160
# Temprature -0.030160
# Taste      -0.062734
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
sns.heatmap(df.corr(method='pearson'))
plt.show()
plt.savefig('heatmap_pearson.png')
plt.clf()
plt.close()
# Out:
# <ipython-input-760-61bf03edf661>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson'))

# %%
correlation_matrix = df.corr().round(5)#round off to 5 decimal values 
sns.heatmap(data=correlation_matrix, annot=True) #annot = True for printing the sin values of the matrix
# Out:
# <ipython-input-761-026da6a1525d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr().round(5)#round off to 5 decimal values
# <Axes: >

# %%
df.isnull().sum()
# Out:
# pH            0
# Temprature    0
# Taste         0
# Odor          0
# Fat           0
# Turbidity     0
# Colour        0
# Grade         0
# dtype: int64

# %% [markdown]
# # Naive Bayes Classification

# %%
df.head()
# Out:
#          pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  0.017857          35      1     0     1          0     254    high
# 1  0.035714          36      0     1     0          1     253    high
# 2  0.642857          70      1     1     1          1     246     low
# 3  0.000000          34      1     1     0          1     255     low
# 4  0.053571          37      0     0     0          0     255  medium

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
encoded=le.fit_transform(df['Grade'])
df['encoded_Combination']=encoded
print(df)
# Out:
#            pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade  \
# 0    0.017857          35      1     0     1          0     254    high
# 1    0.035714          36      0     1     0          1     253    high
# 2    0.642857          70      1     1     1          1     246     low
# 3    0.000000          34      1     1     0          1     255     low
# 4    0.053571          37      0     0     0          0     255  medium
# ..        ...         ...    ...   ...   ...        ...     ...     ...
# 930  0.071429          38      0     1     1          1     255    high
# 942  0.196429          45      1     0     0          1     255  medium
# 957  0.125000          41      1     1     1          0     255    high
# 985  0.196429          45      1     0     0          0     246  medium
# 998  0.160714          43      0     0     0          1     250  medium
#
#      encoded_Combination
# 0                      0
# 1                      0
# ...

# %%
df.columns
# Out:
# Index(['pH', 'Temprature', 'Taste', 'Odor', 'Fat ', 'Turbidity', 'Colour',
#        'Grade', 'encoded_Combination'],
#       dtype='object')

# %%
df.drop(['Fat ','Colour','Taste'],axis='columns',inplace=True)

# %%
df.shape
# Out:
# (83, 6)

# %%
df.columns
# Out:
# Index(['pH', 'Temprature', 'Odor', 'Turbidity', 'Grade',
#        'encoded_Combination'],
#       dtype='object')

# %%
Y=df[['Grade']]
X=df.drop(columns=['Grade'])

# %%
X
# Out:
#            pH  Temprature  Odor  Turbidity  encoded_Combination
# 0    0.017857          35     0          0                    0
# 1    0.035714          36     1          1                    0
# 2    0.642857          70     1          1                    1
# 3    0.000000          34     1          1                    1
# 4    0.053571          37     0          0                    2
# ..        ...         ...   ...        ...                  ...
# 930  0.071429          38     1          1                    0
# 942  0.196429          45     0          1                    2
# 957  0.125000          41     1          0                    0
# 985  0.196429          45     0          0                    2
# 998  0.160714          43     0          1                    2
#
# [83 rows x 5 columns]

# %%
Y
# Out:
#       Grade
# 0      high
# 1      high
# 2       low
# 3       low
# 4    medium
# ..      ...
# 930    high
# 942  medium
# 957    high
# 985  medium
# 998  medium
#
# [83 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
y_train.value_counts()
# Out:
# Grade
# medium    23
# high      21
# low       18
# dtype: int64

# %%
x_train.value_counts()
# Out:
# pH        Temprature  Odor  Turbidity  encoded_Combination
# 0.196429  45          1     1          0                      4
# 0.107143  40          0     0          2                      4
# 0.196429  45          0     1          2                      3
# 0.071429  38          0     0          2                      3
# 0.000000  34          0     1          2                      2
# 0.071429  38          0     0          0                      2
# 0.125000  41          0     0          2                      2
# 0.285714  50          0     0          1                      2
# 0.071429  38          1     1          0                      2
# 0.196429  45          0     0          2                      2
# 0.035714  36          1     0          0                      2
#                       0     0          2                      2
# 0.285714  50          1     1          1                      1
# 0.375000  55          0     0          1                      1
# ...

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (62, 21, 62, 21)

# %%
from sklearn.naive_bayes import GaussianNB
naive=GaussianNB()

# %%
naive_model=naive.fit(x_train,y_train)
naive_model
print('The model has ran succesfully')
# Out:
# The model has ran succesfully
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_test
# Out:
#       Grade
# 30   medium
# 0      high
# 22      low
# 31      low
# 18      low
# 28   medium
# 10   medium
# 76   medium
# 4    medium
# 12      low
# 60   medium
# 33   medium
# 554     low
# 36      low
# 565     low
# 46   medium
# 883    high
# 547  medium
# 82   medium
# 41      low
# 9    medium

# %%
y_test['Predicted']=naive_model.predict(x_test)

# %%
y_test
# Out:
#       Grade Predicted
# 30   medium    medium
# 0      high      high
# 22      low       low
# 31      low       low
# 18      low       low
# 28   medium    medium
# 10   medium    medium
# 76   medium    medium
# 4    medium    medium
# 12      low       low
# 60   medium    medium
# 33   medium    medium
# 554     low       low
# 36      low       low
# 565     low       low
# 46   medium    medium
# 883    high      high
# 547  medium    medium
# 82   medium    medium
# 41      low       low
# 9    medium    medium

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
print(confusion_matrix(y_test['Grade'],y_test['Predicted']))
# Out:
# [[ 2  0  0]
#  [ 0  8  0]
#  [ 0  0 11]]

# %%
accuracy=accuracy_score(y_test['Grade'],y_test['Predicted'])
accuracy=np.round(accuracy,5)

# %%
print('The acccuracy of the model is:',accuracy)
# Out:
# The acccuracy of the model is: 1.0

# %%
print(classification_report(y_test['Grade'],y_test['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00         2
#          low       1.00      1.00      1.00         8
#       medium       1.00      1.00      1.00        11
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %%
d1=X.iloc[15]
d1
# Out:
# pH                      0.071429
# Temprature             38.000000
# Odor                    0.000000
# Turbidity               0.000000
# encoded_Combination     2.000000
# Name: 15, dtype: float64

# %%
val_data=pd.DataFrame(d1)
val_data.transpose()
# Out:
#           pH  Temprature  Odor  Turbidity  encoded_Combination
# 15  0.071429        38.0   0.0        0.0                  2.0

# %%
val_data1=naive_model.predict(val_data.transpose())
print(val_data1)
# Out:
# ['medium']

# %% [markdown]
# # Decision Tree

# %%
#using decision tree model
from sklearn.tree import DecisionTreeClassifier
regressor=DecisionTreeClassifier(criterion='gini',max_depth=5,splitter='best')
X
regressor.fit(x_train,y_train)#training of classifier
y_pred=regressor.predict(val_data.transpose())
print("Prediction: ",y_pred)
# Out:
# Prediction:  ['medium']

# %%
y_test['Predicted_df']=regressor.predict(x_test)
y_test
# Out:
#       Grade Predicted Predicted_df
# 30   medium    medium       medium
# 0      high      high         high
# 22      low       low          low
# 31      low       low          low
# 18      low       low          low
# 28   medium    medium       medium
# 10   medium    medium       medium
# 76   medium    medium       medium
# 4    medium    medium       medium
# 12      low       low          low
# 60   medium    medium       medium
# 33   medium    medium       medium
# 554     low       low          low
# 36      low       low          low
# 565     low       low          low
# 46   medium    medium       medium
# 883    high      high         high
# 547  medium    medium       medium
# 82   medium    medium       medium
# 41      low       low          low
# 9    medium    medium       medium

# %%
print(confusion_matrix(y_test['Grade'],y_test['Predicted']))
# Out:
# [[ 2  0  0]
#  [ 0  8  0]
#  [ 0  0 11]]

# %%
accuracy=accuracy_score(y_test['Grade'],y_test['Predicted_df'])
accuracy=np.round(accuracy,5)
print("Accuracy of the model is:",accuracy)
# Out:
# Accuracy of the model is: 1.0

# %%
df["encoded_Combination"].unique()
# Out:
# array([0, 1, 2])

# %%
df.dtypes
# Out:
# pH                     float64
# Temprature               int64
# Odor                     int64
# Turbidity                int64
# Grade                   object
# encoded_Combination      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['pH', 'Temprature', 'Odor', 'Turbidity', 'Grade',
#        'encoded_Combination'],
#       dtype='object')

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
feature_cols=['pH', 'Temprature', 'Odor', 'Turbidity', 'Grade']
dot_data=StringIO()
#regressor is the decision tree model
#filled= true so that different colours of boxes with different significance
#boxes have rounded corners
#feature names-names of each box , if we dont define it'll take 0,1,2 etc. as default 
export_graphviz(regressor,out_file=dot_data,filled=True,rounded=True,special_characters=True,
                feature_names=feature_cols,class_names=['0', '1', '2'])
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("tree.png")
Image(graph.create_png())

# %% [markdown]
# # Clustering

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd

# %%
df.head()
# Out:
#          pH  Temprature  Odor  Turbidity   Grade  encoded_Combination
# 0  0.017857          35     0          0    high                    0
# 1  0.035714          36     1          1    high                    0
# 2  0.642857          70     1          1     low                    1
# 3  0.000000          34     1          1     low                    1
# 4  0.053571          37     0          0  medium                    2

# %%
df=df.drop(['Odor'],axis="columns")

# %%
df
# Out:
#            pH  Temprature  Turbidity  encoded_Combination
# 0    0.017857          35          0                    0
# 1    0.035714          36          1                    0
# 2    0.642857          70          1                    1
# 3    0.000000          34          1                    1
# 4    0.053571          37          0                    2
# ..        ...         ...        ...                  ...
# 930  0.071429          38          1                    0
# 942  0.196429          45          1                    2
# 957  0.125000          41          0                    0
# 985  0.196429          45          0                    2
# 998  0.160714          43          1                    2
#
# [83 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_df=scaler.fit_transform(df)

# %%
kmeans_model=KMeans(n_clusters=5)
clusters=kmeans_model.fit_predict(scaled_df)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#            pH  Temprature  Turbidity  encoded_Combination
# 0    0.017857          35          0                    0
# 1    0.035714          36          1                    0
# 2    0.642857          70          1                    1
# 3    0.000000          34          1                    1
# 4    0.053571          37          0                    2
# ..        ...         ...        ...                  ...
# 930  0.071429          38          1                    0
# 942  0.196429          45          1                    2
# 957  0.125000          41          0                    0
# 985  0.196429          45          0                    2
# 998  0.160714          43          1                    2
#
# [83 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_df=scaler.fit_transform(df)

# %%
df.dropna(inplace=True)

# %%
#elbow method to find out optimal number of clusters
from sklearn.cluster import KMeans
ssd=[]
for k in range (1,24):
  kmeans_model=KMeans(n_clusters=k)
  kmeans_model.fit(df)
  ssd.append(kmeans_model.inertia_)
plt.figure(figsize=(8,6),dpi=100)
plt.plot(range(1,24),ssd,color="red",marker="o")
plt.xlabel("Number of Clusters")
plt.ylabel("SSD for K")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
df['encoded_Combination'].value_counts()
# Out:
# 2    34
# 1    26
# 0    23
# Name: encoded_Combination, dtype: int64
